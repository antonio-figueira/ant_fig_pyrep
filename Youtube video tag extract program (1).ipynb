# %%
# esta função extrai as tags ou palavras-chave de qualquer vídeo público do youtube a partir do seu link

import urllib.request # módulo de leitura/manipulação de links/urls e conteúdos HTML

def tag_extract(url):
    with urllib.request.urlopen(url) as html: # abre o url
        read_bytes = html.read() # lê o url
    read_text = read_bytes.decode() # descodifica o url lido para formato de texto (HTML)
    tag_lines = []
    tags = []
    lines = read_text.split("\n") # separa o texto do HTML por linhas
    for line in lines:
        if '<meta property="og:video:tag"' in line: # linhas relativas às "tags" começam todas com este formato
            tag_lines.append(line)
    for tag_line in tag_lines:
        tags.append(tag_line[47:-2]) # slice de cada linha com tag de modo a mostrar apenas o nome da tag
    print("\n\033[1mTags identificadas neste vídeo: \033[0m\n")
    for tag in tags:
        print("-->", tag)
    return "\nForam encontradas " + str(len(tags)) + " tags."

# fim, António Figueira (2020)

# %%
# aplicar a função
inp = input("\nLink do vídeo: ")
print(tag_extract(inp))
# Out:
# Link do vídeo: https://www.youtube.com/watch?v=FXQ33kxB1iQ&t=967s
#
# Tags identificadas neste vídeo:
#
# --> mattytingles
# --> asmr
# --> the game store
# --> the gaming store
# --> gamer
# --> streamer
# --> stream
# --> live
# --> ps4
# --> xbox
# --> playstation
# --> sony
# --> camera
# --> relaxing
# --> relaxing asmr
# --> game store matty
# --> gfuel
# --> sponsor
# --> recommended
# --> subscribe
# --> new
# --> like
# --> amazing
# --> sounds
#
# Foram encontradas 24 tags.

# %%
# programa idêntico mas usando o módulo "requests"

import requests

def tag_extract2(url2):
    html2 = requests.get(url2) # obtém o conteúdo HTML do url
    html2_text = html2.text # permite obter o HTML como texto
    tag_lines2 = []
    tags2 = []
    lines2 = html2_text.split("\n") # separa o texto do HTML por linhas
    for line2 in lines2:
        if '<meta property="og:video:tag"' in line2: # linhas relativas às "tags" começam todas com este formato
            tag_lines2.append(line2)
    for tag_line2 in tag_lines2:
        tags2.append(tag_line2[47:-2]) # slice de cada linha com tag de modo a mostrar apenas o nome da tag
    print("\n\033[1mTags identificadas neste vídeo: \033[0m\n")
    for tag2 in tags2:
        print("-->", tag2)
    return "\nForam encontradas " + str(len(tags2)) + " tags."

# aplicar a função
inp2 = input("\nLink do vídeo: ")
print(tag_extract2(inp2))
# Out:
# Link do vídeo: https://www.youtube.com/watch?v=FXQ33kxB1iQ&t=967s
#
# Tags identificadas neste vídeo:
#
# --> mattytingles
# --> asmr
# --> the game store
# --> the gaming store
# --> gamer
# --> streamer
# --> stream
# --> live
# --> ps4
# --> xbox
# --> playstation
# --> sony
# --> camera
# --> relaxing
# --> relaxing asmr
# --> game store matty
# --> gfuel
# --> sponsor
# --> recommended
# --> subscribe
# --> new
# --> like
# --> amazing
# --> sounds
#
# Foram encontradas 24 tags.

# %%
import requests

output = requests.get("https://www.youtube.com/watch?v=WiyIhiYLD7M").text
print(output)
# Out:
# <!DOCTYPE html><html lang="pt-PT" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}</style><script name="www-roboto" >if (document.fonts && document.fonts.load) {document.fonts.load("400 10pt Roboto", "P");document.fonts.load("500 10pt Roboto", "P");}</script><script >var ytcsi = {gt: function(n) {n = (n || '') + 'data_';return ytcsi[n] || (ytcsi[n] = {tick: {},info: {}});},now: (window.performance && window.performance.timing &&window.performance.now && window.performance.timing.navigationStart) ?function() {return window.performance.timing.navigationStart +window.performance.now();} :function() {return (new Date()).getTime();},tick: function(l, t, n) {ticks = ytcsi.gt(n).tick;var v = t || ytcsi.now();if (ticks[l]) {ticks['_' + l] = (ticks['_' + l] || [ticks[l]]);ticks['_' + l].push(v);}ticks[l] = v;},info: function(k, v, n) {ytcsi.gt(n).info[k] = v;},setStart: function(s, t, n) {ytcsi.info('yt_sts', s, n);ytcsi.tick('_start', t, n);}};(function(w, d) {ytcsi.setStart('dhs', w.performance ? w.performance.timing.responseStart : null);var isPrerender = (d.visibilityState || d.webkitVisibilityState) == 'prerender';var vName = (!d.visibilityState && d.webkitVisibilityState)? 'webkitvisibilitychange' : 'visibilitychange';if (isPrerender) {ytcsi.info('prerender', 1);var startTick = function() {ytcsi.setStart('dhs');d.removeEventListener(vName, startTick);};d.addEventListener(vName, startTick, false);}if (d.addEventListener) {d.addEventListener(vName, function() {ytcsi.tick('vc');}, false);}function isGecko() {if (!w.navigator || !w.navigator.userAgent) {return false;}var ua = w.navigator.userAgent;return ua.indexOf('Gecko') > 0 &&ua.toLowerCase().indexOf('webkit') < 0 &&ua.indexOf('Edge') < 0 &&ua.indexOf('Trident') < 0 &&ua.indexOf('MSIE') < 0;}if (isGecko()) {var isHidden = (d.visibilityState || d.webkitVisibilityState) == 'hidden';if (isHidden) {ytcsi.tick('vc');}}var slt = function(el, t) {setTimeout(function() {var n = ytcsi.now();el.loadTime = n;if (el.slt) {el.slt();}}, t);};w.__ytRIL = function(el) {if (!el.getAttribute('data-thumb')) {if (w.requestAnimationFrame) {w.requestAnimationFrame(function() {slt(el, 0);});} else {slt(el, 16);}}};})(window, document);</script><script >var ytcfg = {d: function() {return (window.yt && yt.config_) || ytcfg.data_ || (ytcfg.data_ = {});},get: function(k, o) {return (k in ytcfg.d()) ? ytcfg.d()[k] : o;},set: function() {var a = arguments;if (a.length > 1) {ytcfg.d()[a[0]] = a[1];} else {for (var k in a[0]) {ytcfg.d()[k] = a[0][k];}}}};</script>  <script>ytcfg.set("ROOT_VE_TYPE", 3832);ytcfg.set("EVENT_ID", "uIewXsLPCIWlxN8P75Wd6Ac");</script>
#   <script >ytcfg.set("LACT", null);</script>
# <script >window.yterr = window.yterr || true;</script>
#
#
#
#
#   <script >
#         (function(){/*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# var a={a:"content-snap-width-1",b:"content-snap-width-2",f:"content-snap-width-3"};function f(){var c=[],b;for(b in a)c.push(a[b]);return c}
# function h(c){var b=f().concat(["guide-pinned","show-guide"]),d=b.length,g=[];c.replace(/\S+/g,function(e){for(var k=0;k<d;k++)if(e==b[k])return;g.push(e)});
# return g}
# ;function l(c,b,d){var g=document.getElementsByTagName("html")[0],e=h(g.className);c&&1251<=(window.innerWidth||document.documentElement.clientWidth)&&(e.push("guide-pinned"),b&&e.push("show-guide"));d&&(d=(window.innerWidth||document.documentElement.clientWidth)-21-50,1251<=(window.innerWidth||document.documentElement.clientWidth)&&c&&b&&(d-=230),e.push(1262<=d?"content-snap-width-3":1056<=d?"content-snap-width-2":"content-snap-width-1"));g.className=e.join(" ")}
# var m=["yt","www","masthead","sizing","runBeforeBodyIsReady"],n=this||self;m[0]in n||"undefined"==typeof n.execScript||n.execScript("var "+m[0]);for(var p;m.length&&(p=m.shift());)m.length||void 0===l?n[p]&&n[p]!==Object.prototype[p]?n=n[p]:n=n[p]={}:n[p]=l;}).call(this);
#
#       try {window.ytbuffer = {};ytbuffer.handleClick = function(e) {var element = e.target || e.srcElement;while (element.parentElement) {if (/(^| )yt-can-buffer( |$)/.test(element.className)) {window.ytbuffer = {bufferedClick: e};element.className += ' yt-is-buffered';break;}element = element.parentElement;}};if (document.addEventListener) {document.addEventListener('click', ytbuffer.handleClick);} else {document.attachEvent('onclick', ytbuffer.handleClick);}} catch(e) {}
#
#     yt.www.masthead.sizing.runBeforeBodyIsReady(false,false,true);
#   </script>
#
#       <script src="/yts/jsbin/scheduler-vfl08UJUN/scheduler.js" type="text/javascript" name="scheduler/scheduler" ></script>
#
#
#     <script >var ytimg = {};ytimg.count = 1;ytimg.preload = function(src) {var img = new Image();var count = ++ytimg.count;ytimg[count] = img;img.onload = img.onerror = function() {delete ytimg[count];};img.src = src;};</script>
#
#
#       <script src="/yts/jsbin/www-pagead-id-vflpz_ckT/www-pagead-id.js" type="text/javascript" name="www-pagead-id/www-pagead-id"  async></script>
#
#       <script src="/s/player/64dddad9/player_ias.vflset/pt_PT/base.js"  name="player_ias/base" ></script>
#
#
#
#   <link rel="stylesheet" href="/yts/cssbin/www-core-vflsWry6p.css" name="www-core">
#       <link rel="stylesheet" href="/s/player/64dddad9/www-player.css" name="player/www-player">
#
#   <link rel="stylesheet" href="/yts/cssbin/www-pageframe-vfl2-hqXw.css" name="www-pageframe">
#       <script>ytimg.preload("https:\/\/r2---sn-apn7en7e.googlevideo.com\/generate_204?conn2");ytimg.preload("https:\/\/r2---sn-apn7en7e.googlevideo.com\/generate_204");</script>
#
# <title>Minecraft 1.0.0 - Encantamentos &amp; Nether Ep.6 (PT) - YouTube</title><link rel="canonical" href="https://www.youtube.com/watch?v=WiyIhiYLD7M"><link rel="alternate" media="handheld" href="https://m.youtube.com/watch?v=WiyIhiYLD7M"><link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.youtube.com/watch?v=WiyIhiYLD7M">      <meta name="title" content="Minecraft 1.0.0 - Encantamentos &amp; Nether Ep.6 (PT)">
#
#         <meta name="description" content="1 Like não custa nada.. e ajuda MUITO! --------------------------------------------------------------------------------­--------------------------- Olá pesso...">
#
#       <meta name="keywords" content="sexto, seis, episódio, ep.6, enchanting, encantamentos, sala, room, minecraft, rezpect, rrezpect, portugues, português, portugués, tuga, portuga, lusitano, l...">
#
# <link rel="manifest" href="/manifest.json"><link rel="shortlink" href="https://youtu.be/WiyIhiYLD7M"><link rel="search" type="application/opensearchdescription+xml" href="https://www.youtube.com/opensearch?locale=pt_PT" title="Pesquisa de vídeos do YouTube"><link rel="shortcut icon" href="https://s.ytimg.com/yts/img/favicon-vfl8qSV2F.ico" type="image/x-icon">     <link rel="icon" href="/yts/img/favicon_32-vflOogEID.png" sizes="32x32"><link rel="icon" href="/yts/img/favicon_48-vflVjB_Qk.png" sizes="48x48"><link rel="icon" href="/yts/img/favicon_96-vflW9Ec0w.png" sizes="96x96"><link rel="icon" href="/yts/img/favicon_144-vfliLAfaB.png" sizes="144x144"><meta name="theme-color" content="#ff0000">        <link rel="alternate" href="android-app://com.google.android.youtube/http/www.youtube.com/watch?v=WiyIhiYLD7M">
#     <link rel="alternate" href="ios-app://544007664/vnd.youtube/www.youtube.com/watch?v=WiyIhiYLD7M">
#
#       <link rel="alternate" type="application/json+oembed" href="http://www.youtube.com/oembed?format=json&amp;url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DWiyIhiYLD7M" title="Minecraft 1.0.0 - Encantamentos &amp; Nether Ep.6 (PT)">
#   <link rel="alternate" type="text/xml+oembed" href="http://www.youtube.com/oembed?format=xml&amp;url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DWiyIhiYLD7M" title="Minecraft 1.0.0 - Encantamentos &amp; Nether Ep.6 (PT)">
#
#         <meta property="og:site_name" content="YouTube">
#       <meta property="og:url" content="https://www.youtube.com/watch?v=WiyIhiYLD7M">
#     <meta property="og:title" content="Minecraft 1.0.0 - Encantamentos &amp; Nether Ep.6 (PT)">
#     <meta property="og:image" content="https://i.ytimg.com/vi/WiyIhiYLD7M/maxresdefault.jpg">
#     <meta property="og:image:width" content="1280">
#     <meta property="og:image:height" content="720">
#
#       <meta property="og:description" content="1 Like não custa nada.. e ajuda MUITO! --------------------------------------------------------------------------------­--------------------------- Olá pesso...">
#
#     <meta property="al:ios:app_store_id" content="544007664">
#     <meta property="al:ios:app_name" content="YouTube">
#       <meta property="al:ios:url" content="vnd.youtube://www.youtube.com/watch?v=WiyIhiYLD7M&amp;feature=applinks">
#
#       <meta property="al:android:url" content="vnd.youtube://www.youtube.com/watch?v=WiyIhiYLD7M&amp;feature=applinks">
#     <meta property="al:android:app_name" content="YouTube">
#     <meta property="al:android:package" content="com.google.android.youtube">
#     <meta property="al:web:url" content="https://www.youtube.com/watch?v=WiyIhiYLD7M&amp;feature=applinks">
#
#     <meta property="og:type" content="video.other">
#       <meta property="og:video:url" content="https://www.youtube.com/embed/WiyIhiYLD7M">
#       <meta property="og:video:secure_url" content="https://www.youtube.com/embed/WiyIhiYLD7M">
#       <meta property="og:video:type" content="text/html">
#       <meta property="og:video:width" content="1280">
#       <meta property="og:video:height" content="720">
#
#         <meta property="og:video:tag" content="sexto">
#         <meta property="og:video:tag" content="seis">
#         <meta property="og:video:tag" content="episódio">
#         <meta property="og:video:tag" content="ep.6">
#         <meta property="og:video:tag" content="enchanting">
#         <meta property="og:video:tag" content="encantamentos">
#         <meta property="og:video:tag" content="sala">
#         <meta property="og:video:tag" content="room">
#         <meta property="og:video:tag" content="minecraft">
#         <meta property="og:video:tag" content="rezpect">
#         <meta property="og:video:tag" content="rrezpect">
#         <meta property="og:video:tag" content="portugues">
#         <meta property="og:video:tag" content="português">
#         <meta property="og:video:tag" content="portugués">
#         <meta property="og:video:tag" content="tuga">
#         <meta property="og:video:tag" content="portuga">
#         <meta property="og:video:tag" content="lusitano">
#         <meta property="og:video:tag" content="luso">
#         <meta property="og:video:tag" content="1.0.0">
#         <meta property="og:video:tag" content="realease">
#         <meta property="og:video:tag" content="nova">
#         <meta property="og:video:tag" content="versão">
#         <meta property="og:video:tag" content="início">
#         <meta property="og:video:tag" content="survival">
#         <meta property="og:video:tag" content="hardcore">
#         <meta property="og:video:tag" content="sobrevivência">
#         <meta property="og:video:tag" content="sobrevivencia">
#         <meta property="og:video:tag" content="mapa">
#         <meta property="og:video:tag" content="custom">
#         <meta property="og:video:tag" content="seed">
#         <meta property="og:video:tag" content="respect">
#         <meta property="og:video:tag" content="rrespect">
#         <meta property="og:video:tag" content="picareta">
#         <meta property="og:video:tag" content="pickhaxe">
#         <meta property="og:video:tag" content="tree">
#         <meta property="og:video:tag" content="arvore">
#         <meta property="og:video:tag" content="crafting">
#         <meta property="og:video:tag" content="jgbb">
#         <meta property="og:video:tag" content="iseedeadcreepers">
#         <meta property="og:video:tag" content="sickoz">
#         <meta property="og:video:tag" content="fred">
#         <meta property="og:video:tag" content="fredever">
#         <meta property="og:video:tag" content="mrnikkihd">
#         <meta property="og:video:tag" content="venom_extreme">
#         <meta property="og:video:tag" content="feromonas">
#         <meta property="og:video:tag" content="Brazil">
#         <meta property="og:video:tag" content="release">
#         <meta property="og:video:tag" content="brasil">
#         <meta property="og:video:tag" content="zuka">
#         <meta property="og:video:tag" content="zuca">
#         <meta property="og:video:tag" content="pt-pt">
#         <meta property="og:video:tag" content="pt-br">
#         <meta property="og:video:tag" content="portugal">
#
#     <meta property="fb:app_id" content="87741124305">
#
#         <meta name="twitter:card" content="player">
#     <meta name="twitter:site" content="@youtube">
#     <meta name="twitter:url" content="https://www.youtube.com/watch?v=WiyIhiYLD7M">
#     <meta name="twitter:title" content="Minecraft 1.0.0 - Encantamentos &amp; Nether Ep.6 (PT)">
#     <meta name="twitter:description" content="1 Like não custa nada.. e ajuda MUITO! --------------------------------------------------------------------------------­--------------------------- Olá pesso...">
#     <meta name="twitter:image" content="https://i.ytimg.com/vi/WiyIhiYLD7M/maxresdefault.jpg">
#     <meta name="twitter:app:name:iphone" content="YouTube">
#     <meta name="twitter:app:id:iphone" content="544007664">
#     <meta name="twitter:app:name:ipad" content="YouTube">
#     <meta name="twitter:app:id:ipad" content="544007664">
#       <meta name="twitter:app:url:iphone" content="vnd.youtube://www.youtube.com/watch?v=WiyIhiYLD7M&amp;feature=applinks">
#       <meta name="twitter:app:url:ipad" content="vnd.youtube://www.youtube.com/watch?v=WiyIhiYLD7M&amp;feature=applinks">
#     <meta name="twitter:app:name:googleplay" content="YouTube">
#     <meta name="twitter:app:id:googleplay" content="com.google.android.youtube">
#     <meta name="twitter:app:url:googleplay" content="https://www.youtube.com/watch?v=WiyIhiYLD7M">
#       <meta name="twitter:player" content="https://www.youtube.com/embed/WiyIhiYLD7M">
#       <meta name="twitter:player:width" content="1280">
#       <meta name="twitter:player:height" content="720">
#
# <style>.exp-invert-logo .hats-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_mini_gray-vflfanGkh.png);width: 65px;height: 15px;}.exp-invert-logo #header:before,.exp-invert-logo .ypc-join-family-header .logo,.exp-invert-logo #footer-logo .footer-logo-icon,.exp-invert-logo #yt-masthead #logo-container .logo,.exp-invert-logo #masthead #logo-container,.exp-invert-logo .admin-masthead-logo a,.exp-invert-logo #yt-sidebar-styleguide-logo #logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_small-vflHpzGZm.png);width: 100px;height: 30px;}.exp-invert-logo.inverted-hdpi #header:before,.exp-invert-logo.inverted-hdpi .ypc-join-family-header .logo,.exp-invert-logo.inverted-hdpi #footer-logo .footer-logo-icon,.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo,.exp-invert-logo.inverted-hdpi #masthead #logo-container,.exp-invert-logo.inverted-hdpi .admin-masthead-logo a,.exp-invert-logo.inverted-hdpi #yt-sidebar-styleguide-logo #logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_small_2x-vfl4_cFqn.png);background-size: 100px 30px;width: 100px;height: 30px;}.exp-invert-logo.exp-fusion-nav-redesign .masthead-logo-renderer-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi.exp-fusion-nav-redesign .masthead-logo-renderer-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);width: 40px;height: 28px;}@media screen and (max-width: 656px) {.exp-invert-logo #yt-masthead #logo-container .logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);background-size: 40px 28px;width: 40px;height: 28px;}}@media only screen and (min-width: 0px) and (max-width: 498px),only screen and (min-width: 499px) and (max-width: 704px) {.exp-invert-logo.exp-responsive #yt-masthead #logo-container {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi.exp-responsive #yt-masthead #logo-container {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);background-size: 40px 28px;width: 40px;height: 28px;}}.exp-invert-logo #yt-masthead #logo-container .logo-red {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_red-vflZxcSR1.png);width: 132px;height: 30px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo-red {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_red_2x-vflOSHA_n.png);background-size: 132px 30px;width: 132px;height: 30px;}.exp-invert-logo #yt-masthead #logo-container .logo-premium {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_premium-vfltrvziB.png);width: 108px;height: 30px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo-premium {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_premium_2x-vflxcbz_g.png);background-size: 108px 30px;width: 108px;height: 30px;}.exp-invert-logo .guide-item .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red-vflovGTdz.png);width: 20px;height: 20px;}.exp-invert-logo.inverted-hdpi .guide-item .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red_2x-vflqMdgEM.png);background-size: 20px 20px;width: 20px;height: 20px;}.exp-invert-logo .guide-item:hover .guide-video-youtube-red-icon,.exp-invert-logo .guide-item.guide-item-selected .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red_hover-vflgV4Gv0.png);width: 20px;height: 20px;}.exp-invert-logo.inverted-hdpi .guide-item:hover .guide-video-youtube-red-icon,.exp-invert-logo.inverted-hdpi .guide-item.guide-item-selected .guide-video-youtube-red-icon {background: no- ...
# <div id="early-body"></div><div id="body-container"><div id="a11y-announcements-container" role="alert"><div id="a11y-announcements-message"></div></div><form name="logoutForm" method="POST" action="/logout"><input type="hidden" name="action_logout" value="1"></form><div id="masthead-positioner">  <div id="ticker-content">
#
#
#   </div>
#   <div id="yt-masthead-container" class="clearfix yt-base-gutter">  <button id="a11y-skip-nav" class="skip-nav" data-target-id="main" tabindex="3">
# Ignorar navegação
#   </button>
# <div id="yt-masthead"><div class="yt-masthead-logo-container ">  <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-text yt-uix-button-empty yt-uix-button-has-icon appbar-guide-toggle appbar-guide-clickable-ancestor" type="button" onclick=";return false;" aria-controls="appbar-guide-menu" id="appbar-guide-button" aria-label="Guia"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-appbar-guide yt-sprite"></span></span></button>
#   <div id="appbar-main-guide-notification-container"></div>
#     <a id="logo-container" href="/" title="Página inicial do YouTube" class=" spf-link  masthead-logo-renderer yt-uix-sessionlink" data-sessionlink=""><span title="Página inicial do YouTube" class="logo masthead-logo-renderer-logo yt-sprite"></span><span class="content-region">PT</span></a>
# </div><div id="yt-masthead-signin">    <a  href="//www.youtube.com/upload" class="yt-uix-button   yt-uix-sessionlink yt-uix-button-opacity yt-uix-button-size-default yt-uix-button-has-icon yt-uix-tooltip yt-uix-button-empty" data-sessionlink="ei=uIewXsLPCIWlxN8P75Wd6Ac&amp;feature=mhsb" id="upload-btn" title="Carregar"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-material-upload yt-sprite"></span></span></a>
# <div class="signin-container "><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-primary" type="button" onclick=";window.location.href=this.getAttribute(&#39;href&#39;);return false;" role="link" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;hl=pt-PT&amp;uilel=3&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fnext%3D%252Fwatch%253Fv%253DWiyIhiYLD7M%26hl%3Dpt-PT%26feature%3Dsign_in_button%26app%3Ddesktop%26action_handle_signin%3Dtrue&amp;passive=true"><span class="yt-uix-button-content">Iniciar sessão</span></button>  <iframe id="signin-passive" src="https://accounts.google.com/ServiceLogin?service=youtube&amp;hl=pt-PT&amp;uilel=3&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fnext%3D%252Fsignin_passive%26hl%3Dpt-PT%26feature%3Dpassive%26app%3Ddesktop%26action_handle_signin%3Dtrue&amp;passive=true"></iframe>
# </div></div><div id="yt-masthead-content"><form id="masthead-search" class="  search-form consolidated-form  vve-check" action="/results" onsubmit="if (document.getElementById(&#39;masthead-search-term&#39;).value == &#39;&#39;) return false;" data-clicktracking="CAEQ7VAiEwjCi6aXkpvpAhWFEvEFHe9KB30o-B0" data-visibility-tracking="CAEQ7VAiEwjCi6aXkpvpAhWFEvEFHe9KB30o-B0"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default search-btn-component search-button" type="submit" onclick="if (document.getElementById(&#39;masthead-search-term&#39;).value == &#39;&#39;) return false; document.getElementById(&#39;masthead-search&#39;).submit(); return false;;return true;" id="search-btn" tabindex="2" dir="ltr"><span class="yt-uix-button-content">Pesquisar</span></button><div id="masthead-search-terms" class="masthead-search-terms-border" dir="ltr"><input id="masthead-search-term" autocomplete="off"  onkeydown="if (!this.value &amp;&amp; (event.keyCode == 40 || event.keyCode == 32 || event.keyCode == 34)) {this.onkeydown = null; this.blur();}" class="search-term masthead-search-renderer-input yt-uix-form-input-bidi" name="search_query" value="" type="text" tabindex="1" placeholder="Pesquisa" title="Pesquisar" aria-label="Pesquisar"></div></form></div></div></div>
#     <div id="masthead-appbar-container" class="clearfix"><div id="masthead-appbar"><div id="appbar-content" class=""></div></div></div>
#
# </div><div id="masthead-positioner-height-offset"></div><div id="page-container"><div id="page" class="  watch        video-WiyIhiYLD7M clearfix"><div id="guide" class="yt-scrollbar">    <div id="appbar-guide-menu" class="appbar-menu appbar-guide-menu-layout appbar-guide-clickable-ancestor">
#     <div id="guide-container">
#       <div class="guide-module-content guide-module-loading">
#           <p class="yt-spinner ">
#         <span title="Ícone A carregar" class="yt-spinner-img  yt-sprite"></span>
#
#     <span class="yt-spinner-message">
# A carregar...
#     </span>
#   </p>
#
#       </div>
#     </div>
#   </div>
#
# </div><div class="alerts-wrapper"><div id="alerts" class="content-alignment">    <div class="yt-alert yt-alert-default yt-alert-warn  " id="old-browser-alert">  <div class="yt-alert-icon">
#     <span class="icon master-sprite yt-sprite"></span>
#   </div>
# <div class="yt-alert-content" role="alert">    <div class="yt-alert-message" tabindex="0">
#             Deixaremos de suportar este navegador em breve. Para obter a melhor experiência, <a href="/supported_browsers">atualize o navegador</a>.
#
#     </div>
# </div><div class="yt-alert-buttons"></div></div>
#
#   <div id="editor-progress-alert-container"></div>
#   <div class="yt-alert yt-alert-default yt-alert-warn hid " id="editor-progress-alert-template">  <div class="yt-alert-icon">
#     <span class="icon master-sprite yt-sprite"></span>
#   </div>
# <div class="yt-alert-content" role="alert"></div><div class="yt-alert-buttons"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-close close yt-uix-close" type="button" onclick=";return false;" aria-label="Fechar" data-close-parent-class="yt-alert"><span class="yt-uix-button-content">Fechar</span></button></div></div>
#
#
# </div></div><div id="header"></div><div id="player" class="  content-alignment       watch-small  " role="complementary"><div id="theater-background" class="player-height"></div>  <div id="player-mole-container">
#     <div id="player-unavailable" class="    hid    player-width player-height    player-unavailable ">
#               <img class="icon meh" src="/yts/img/pixel-vfl3z5WfW.gif" data-icon="/yts/img/meh7-vflGevej7.png" alt="">
#   <div class="content">
#     <h1 id="unavailable-message" class="message">
#               Este vídeo não está disponível.
#
#     </h1>
#     <div id="unavailable-submessage" class="submessage">
#     </div>
#   </div>
#
#
#     </div>
#
#     <div id="player-api" class="player-width player-height off-screen-target player-api" tabIndex="-1"></div>
#         <script >if (window.ytcsi) {window.ytcsi.tick("cfg", null, '');}</script>
#     <script >var ytplayer = ytplayer || {};ytplayer.config = {"attrs":{"id":"movie_player"},"args":{"host_language":"pt-PT","cr":"PT","csi_page_type":"watch","innertube_api_key":"AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8","vss_host":"s.youtube.com","fexp":"23744176,23804281,23837040,23837993,23839597,23856950,23857949,23859802,23860859,23865857,23866399,23866661,23868333,23876177,23876458,23877107,23877889,23880389,23880619,23882034,23882502,23882513,23884387,23885293,23885571,23886825,23890960,23891425,23891461,23891461,23892587,23893484,23895672,23896801,23898053,23898165,23898634,23899054,23899262,23899989,23901016,9449243,9471235","c":"WEB","cver":"1.20200429.03.00","fflags":"html5_set_exception_to_nonfatal=true\u0026mweb_enable_custom_control_shared=true\u0026html5_deadzone_multiplier=1.0\u0026html5_desktop_vr180_allow_panning=true\u0026html5_continue_probing_on_missing_drminfo=true\u0026desktop_sparkles_light_cta_button=true\u0026web_gel_debounce_ms=10000\u0026hfr_dropped_framerate_fallback_threshold=0\u0026html5_log_non_fatal=true\u0026html5_vp9_mime_full_range_flag=true\u0026polymer_bad_build_labels=true\u0026html5_seek_set_cmt_delay_ms=2000\u0026html5_inline_video_quality_survey=true\u0026desktop_videowall_companion_wta_support=true\u0026html5_gllat=true\u0026html5_subsegment_readahead_seek_latency_fudge=0.5\u0026html5_rewrite_manifestless_for_continuity=true\u0026mark_encrypted_webm_supporting_widevine=true\u0026html5_no_placeholder_rollbacks=true\u0026html5_remove_pause=false\u0026player_destroy_old_version=true\u0026max_resolution_for_white_noise=360\u0026autoplay_time=8000\u0026html5_qoe_reports_ctt=true\u0026live_fresca_scheduled_persistent=true\u0026bulleit_get_midroll_info_timeout_ms=8000\u0026hide_preskip=true\u0026midroll_notify_time_seconds=5\u0026html5_live_normal_latency_bandwidth_window=0.0\u0026html5_player_dynamic_bottom_gradient=true\u0026html5_gapless_error_check_killswitch=true\u0026skip_ad_button_with_thumbnail=true\u0026html5_subsegment_readahead_min_buffer_health_secs_on_timeout=0.1\u0026disable_legacy_desktop_remote_queue=true\u0026html5_allow_video_keyframe_without_audio=true\u0026html5_restrict_streaming_xhr_on_sqless_requests=true\u0026html5_manifestless_live_segment_index_new_logic=true\u0026set_interstitial_advertisers_question_text=true\u0026web_screen_associated_all_layers=true\u0026use_http_post_for_unplugged_get_midroll_info=true\u0026web_player_inline_botguard=true\u0026html5_enable_ac3=true\u0026html5_optimized_polling=true\u0026html5_manifestless_interpolate=true\u0026simply_enable_botguard=true\u0026html5_av1_thresh_arm=240\u0026web_player_icons=true\u0026html5_hack_gapless_init=true\u0026html5_subsegment_readahead_target_buffer_health_secs=0.5\u0026html5_health_to_gel=true\u0026html5_default_quality_cap=720\u0026render_enhanced_overlays_as_ctas_for_desktop_style=unset\u0026html5_gl_fps_threshold=0\u0026html5_max_headm_for_streaming_xhr=0\u0026html5_min_upgrade_health=0\u0026web_player_sentinel_is_uniplayer=true\u0026release_player_on_abandon_for_bulleit_lr_ads_frontend=true\u0026populate_companion_metadata_from_vms_html5=true\u0026html5_av1_thresh=1080\u0026web_op_signal_type_blacklist=()\u0026botguard_async_snapshot_timeout_ms=2000\u0026disable_simple_mixed_direction_formatted_strings=true\u0026enable_live_premiere_web_player_indicator=true\u0026html5_max_live_dvr_window_plus_margin_secs=46800.0\u0026html5_post_interrupt_readahead=20\u0026html5_long_rebuffer_threshold_ms=30000\u0026web_api_url=true\u0026html5_media_fullscreen=true\u0026player_enable_playback_playlist_change=true\u0026html5_unrewrite_timestamps=true\u0026live_fresca_v2=true\u0026mweb_muted_autoplay_animation=shrink\u0026html5_disable_extra_update_resource=true\u0026html5_max_readahead_bandwidth_cap=0\u0026html5_allowable_liveness_drift_chunks=2\u0026web_player_ios_mweb_resizing=true\u0026html5_dai_assume_unordered_cuepoints=true\u0026web_network_combined_catch=true\u0026web_player_watch_next_response=true\u0026desktop ...
#
#
#     <div id="watch-queue-mole" class="video-mole mole-collapsed hid"><div id="watch-queue" class="watch-playlist player-height"><div class="main-content"><div class="watch-queue-header"><div class="watch-queue-info"><div class="watch-queue-info-icon"><span class="tv-queue-list-icon yt-sprite"></span></div><h3 class="watch-queue-title">Fila de espera de visualizações</h3><h3 class="tv-queue-title">Fila</h3><span class="tv-queue-details"></span></div><div class="watch-queue-control-bar control-bar-button"><div class="watch-queue-mole-info"><div class="watch-queue-control-bar-icon"><span class="watch-queue-icon yt-sprite"></span></div><div class="watch-queue-title-container"><span class="watch-queue-count"></span><span class="watch-queue-title">Fila de espera de visualizações</span><span class="tv-queue-title">Fila</span></div></div>  <span class="dark-overflow-action-menu">
#
#
#     <button aria-expanded="false" type="button" onclick=";return false;" aria-haspopup="true" aria-label="Ações da fila" class="flip control-bar-button yt-uix-button yt-uix-button-dark-overflow-action-menu yt-uix-button-size-default yt-uix-button-has-icon no-icon-markup yt-uix-button-empty" ><span class="yt-uix-button-arrow yt-sprite"></span><ul class="watch-queue-menu yt-uix-button-menu yt-uix-button-menu-dark-overflow-action-menu hid" role="menu" aria-haspopup="true"><li role="menuitem"><span onclick=";return false;" class="watch-queue-menu-choice overflow-menu-choice yt-uix-button-menu-item" data-action="remove-all" >Remover tudo</span></li><li role="menuitem"><span onclick=";return false;" class="watch-queue-menu-choice overflow-menu-choice yt-uix-button-menu-item" data-action="disconnect" >Desassociar</span></li></ul></button>
#   </span>
#   <div class="watch-queue-controls">
#     <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button prev-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" type="button" onclick=";return false;" title="Vídeo anterior"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-prev yt-sprite"></span></span></button>
#
#     <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button play-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" type="button" onclick=";return false;" title="Jogar"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-play yt-sprite"></span></span></button>
#
#     <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button pause-watch-queue-button yt-uix-button-opacity yt-uix-tooltip hid yt-uix-tooltip" type="button" onclick=";return false;" title="Interromper"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-pause yt-sprite"></span></span></button>
#
#     <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button next-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" type="button" onclick=";return false;" title="Vídeo seguinte"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-next yt-sprite"></span></span></button>
#   </div>
# </div><div class="autoplay-dismiss-bar fade-out"><span class="autoplay-dismiss-title-label">O próximo vídeo está a iniciar</span><span><button class="yt-uix-button yt-uix-button-size-default autoplay-dismiss-button yt-uix-tooltip" type="button" onclick=";return false;" title="parar"><span class="yt-uix-button-content">parar</span></button></span></div></div><div class="watch-queue-items-container yt-scrollbar-dark yt-scrollbar"><div class="yt-uix-scroller playlist-videos-list"><ol class="watch-queue-items-list" data-scroll-action="yt.www.watchqueue.loadThumbnails">  <p class="yt-spinner ">
#         <span title="Ícone A carregar" class="yt-spinner-img  yt-sprite"></span>
#
#     <span class="yt-spinner-message">
# A carregar...
#     </span>
#   </p>
# </ol><div class="autoplay-control-container yt-uix-scroller-scroll-unit hid">  <div class="autoplay-control-bar">
#     <label class="autoplay-label" for=autoplay-toggle-id></label>
#     <label class="yt-uix-form-input-checkbox-container yt-uix-form-input-container yt-uix-form-input-paper-toggle-container  "><input class="yt-uix-form-input-checkbox" type="checkbox" id="autoplay-toggle-id"/><div class="yt-uix-form-input-paper-toggle-bg yt-uix-form-input-paper-toggle-bar"></div><div class="yt-uix-form-input-paper-toggle-bg yt-uix-form-input-paper-toggle-button"></div></label>
#   </div>
# </div><div class="up-next-item-container hid"></div></div></div></div>  <div class="hid">
#     <div id="watch-queue-title-msg">
# Fila de espera de visualizações
#     </div>
#
#     <div id="tv-queue-title-msg">Fila</div>
#
#     <div id="watch-queue-count-msg">
# __count__/__total__
#     </div>
#
#     <div id="watch-queue-loading-template">
#       <!--
#           <p class="yt-spinner ">
#         <span title="Ícone A carregar" class="yt-spinner-img  yt-sprite"></span>
#
#     <span class="yt-spinner-message">
# A carregar...
#     </span>
#   </p>
#
#       -->
#     </div>
#   </div>
# </div></div>
#     <div id="player-playlist" class="  content-alignment    watch-player-playlist  ">
#
#
#     </div>
#
#   </div>
#
#   <div class="clear"></div>
# </div><div id="content" class="  content-alignment" role="main">      <div id="placeholder-player">
#     <div class="player-api player-width player-height"></div>
#   </div>
#
#   <div id="watch7-container" class="">
#       <div id="player-messages">
#           <div class="yt-dialog hid mealbar-promo-renderer">
#     <div class="yt-dialog-base">
#       <span class="yt-dialog-align"></span>
#       <div class="yt-dialog-fg" role="dialog">
#         <div class="yt-dialog-fg-content">
#             <div class="yt-dialog-header">
#                   <h2 class="yt-dialog-title" role="alert">
#       YouTube Premium
#   </h2>
#
#             </div>
#           <div class="yt-dialog-loading">
#               <div class="yt-dialog-waiting-content">
#       <p class="yt-spinner ">
#         <span title="Ícone A carregar" class="yt-spinner-img  yt-sprite"></span>
#
#     <span class="yt-spinner-message">
# A carregar...
#     </span>
#   </p>
#
#   </div>
#
#           </div>
#           <div class="yt-dialog-content">
#                 <div class="mealbar-promo-message" tabindex="0">Obtenha o YouTube sem os anúncios</div>
#
#           </div>
#           <div class="yt-dialog-working">
#               <div class="yt-dialog-working-overlay"></div>
#   <div class="yt-dialog-working-bubble">
#     <div class="yt-dialog-waiting-content">
#         <p class="yt-spinner ">
#         <span title="Ícone A carregar" class="yt-spinner-img  yt-sprite"></span>
#
#     <span class="yt-spinner-message">
#         A executar...
#     </span>
#   </p>
#
#       </div>
#   </div>
#
#           </div>
# <div class="yt-dialog-footer">      <span class="generic-promo-impression-logging">
#         <span data-feedback-token="AB9zfpLZZBEGDtF0hBSyxoehJ6SnKZ70mg3yu5S6L22QLR4h6qBZA3j5iwcIyw7kB0QeuwhSog52pT7sdaxJX-SIODXPSYPur3N83cX1FFCBdQ0IjBa6XglHShWNoumXmbyezGXIgwhAAoVBqed1e3Hwvxz5FAMqlQ" class="generic-promo-impression-feedback"></span>
#     </span>
#
#
#
#
#
#
#
#
#
#
#
#
#
#             <div class="service-endpoint-action-container hid">
#     </div>
#
#
#       <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-blue-text  vve-check yt-uix-servicelink dismiss-menu-choice" type="button" onclick=";return false;" data-feedback-token="AB9zfpJfA0PbyURKN2dNoHhs0BzVJ6l1m-fA_qITc5jOtGRHWGbEJqUztEf1QYbZG6WOJ_RdQVJwKlfLkX7w3-CADVQLx1Ouuj0L7k2fmtQtU5FtxwCmS3SNiBLzt_w07irCMfz62qOz5a1372RhloiAkxrN6Bx3kw" data-servicelink="CAIQ7W8iEwjvlqiXkpvpAhUrGfEFHaqfC6c" data-visibility-tracking="CAIQ7W8iEwjvlqiXkpvpAhUrGfEFHaqfC6c" data-action="hide"><span class="yt-uix-button-content">Ignorar teste</span></button>
#
#
#
#
#
#
#
#
#
#
#
#
#             <div class="service-endpoint-action-container hid">
#     </div>
#
#
#       <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-primary  vve-check dismiss-menu-choice" type="button" onclick=";return false;" data-sessionlink="itct=CAMQ7G8iEwjvlqiXkpvpAhUrGfEFHaqfC6c" data-feedback-token="AB9zfpKbi94N33NwKSz2GWlr9xrOya1rqRE9e741FGo_KNlAxu--k3N9-IihnHnqE8M5Oaqv4rCBk24W-k7Q2wuUrJhn6qjzaZPPD52o0FoWwtF3paGD6Flln__8JQAi2obSPbatOscFD1R8dX9VZe3yn8Joiz4DPQ" data-redirect-url="/premium?ybp=Eg9GRXdoYXRfdG9fd2F0Y2gqEmRtZWEtYWNxLWMtZWdzb1ZEYToaCAYYASoUChJkbWVhLWFjcS1jLWVnc29WRGE%253D" data-visibility-tracking="CAMQ7G8iEwjvlqiXkpvpAhUrGfEFHaqfC6c" data-action="hide"><span class="yt-uix-button-content">1 mês grátis</span></button>
# </div>        </div>
#         <div class="yt-dialog-focus-trap" tabindex="0"></div>
#       </div>
#     </div>
#   </div>
# <div class="mealbar-visibility" data-trigger-condition="TRIGGER_CONDITION_POST_AD" data-lact-th="" data-prompt-del-sec="" data-visibility-tracking="CAEQ42kYACITCO-WqJeSm-kCFSsZ8QUdqp8Lpw=="></div>
#   </div>
#   <div id="watch7-main-container">
#     <div id="watch7-main" class="clearfix">
#       <div id="watch7-preview" class="player-width player-height hid">
#       </div>
#       <div id="watch7-content" class="watch-main-col " itemscope itemid="" itemtype="http://schema.org/VideoObject"
#       >
#               <link itemprop="url" href="https://www.youtube.com/watch?v=WiyIhiYLD7M">
#     <meta itemprop="name" content="Minecraft 1.0.0 - Encantamentos &amp; Nether Ep.6 (PT)">
#     <meta itemprop="description" content="1 Like não custa nada.. e ajuda MUITO! --------------------------------------------------------------------------------­--------------------------- Olá pesso...">
#
#
#     <meta itemprop="paid" content="False">
#
#       <meta itemprop="channelId" content="UC5dbbmnZOPnRAMOcUTgEVSQ">
#       <meta itemprop="videoId" content="WiyIhiYLD7M">
#
#       <meta itemprop="duration" content="PT19M42S">
#       <meta itemprop="unlisted" content="False">
#
#         <span itemprop="author" itemscope itemtype="http://schema.org/Person">
#           <link itemprop="url" href="http://www.youtube.com/user/RRezpect">
#         </span>
#
#         <script type="application/ld+json" >
#   {
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#       {
#         "@type": "ListItem",
#         "position": 1,
#         "item": {
#           "@id": "http:\/\/www.youtube.com\/user\/RRezpect",
#           "name": "Rezpect"
#         }
#       }
#     ]
#   }
#   </script>
#
#
#     <link itemprop="thumbnailUrl" href="https://i.ytimg.com/vi/WiyIhiYLD7M/maxresdefault.jpg">
#     <span itemprop="thumbnail" itemscope itemtype="http://schema.org/ImageObject">
#       <link itemprop="url" href="https://i.ytimg.com/vi/WiyIhiYLD7M/maxresdefault.jpg">
#       <meta itemprop="width" content="1280">
#       <meta itemprop="height" content="720">
#     </span>
#
#       <link itemprop="embedUrl" href="https://www.youtube.com/embed/WiyIhiYLD7M">
#       <meta itemprop="playerType" content="HTML5 Flash">
#       <meta itemprop="width" content="1280">
#       <meta itemprop="height" content="720">
#
#       <meta itemprop="isFamilyFriendly" content="True">
#       <meta itemprop="regionsAllowed" content="AD,AE,AF,AG,AI,AL,AM,AO,AQ,AR,AS,AT,AU,AW,AX,AZ,BA,BB,BD,BE,BF,BG,BH,BI,BJ,BL,BM,BN,BO,BQ,BR,BS,BT,BV,BW,BY,BZ,CA,CC,CD,CF,CG,CH,CI,CK,CL,CM,CN,CO,CR,CU,CV,CW,CX,CY,CZ,DE,DJ,DK,DM,DO,DZ,EC,EE,EG,EH,ER,ES,ET,FI,FJ,FK,FM,FO,FR,GA,GB,GD,GE,GF,GG,GH,GI,GL,GM,GN,GP,GQ,GR,GS,GT,GU,GW,GY,HK,HM,HN,HR,HT,HU,ID,IE,IL,IM,IN,IO,IQ,IR,IS,IT,JE,JM,JO,JP,KE,KG,KH,KI,KM,KN,KP,KR,KW,KY,KZ,LA,LB,LC,LI,LK,LR,LS,LT,LU,LV,LY,MA,MC,MD,ME,MF,MG,MH,MK,ML,MM,MN,MO,MP,MQ,MR,MS,MT,MU,MV,MW,MX,MY,MZ,NA,NC,NE,NF,NG,NI,NL,NO,NP,NR,NU,NZ,OM,PA,PE,PF,PG,PH,PK,PL,PM,PN,PR,PS,PT,PW,PY,QA,RE,RO,RS,RU,RW,SA,SB,SC,SD,SE,SG,SH,SI,SJ,SK,SL,SM,SN,SO,SR,SS,ST,SV,SX,SY,SZ,TC,TD,TF,TG,TH,TJ,TK,TL,TM,TN,TO,TR,TT,TV,TW,TZ,UA,UG,UM,US,UY,UZ,VA,VC,VE,VG,VI,VN,VU,WF,WS,YE,YT,ZA,ZM,ZW">
#       <meta itemprop="interactionCount" content="8106">
#       <meta itemprop="datePublished" content="2011-12-08">
#       <meta itemprop="uploadDate" content="2011-12-08">
#       <meta itemprop="genre" content="Gaming">
#
#
#
#       <div id="watch-header" class="yt-card yt-card-has-padding">
#       <div id="watch7-headline" class="clearfix">
#     <div id="watch-headline-title">
#       <h1 class="watch-title-container" >
#
#
#
#   <span id="eow-title" class="watch-title" dir="ltr" title="Minecraft 1.0.0 - Encantamentos &amp; Nether Ep.6 (PT)">
#     Minecraft 1.0.0 - Encantamentos &amp; Nether Ep.6 (PT)
#   </span>
#
#       </h1>
#     </div>
#   </div>
#
#     <div id="watch7-user-header" class=" spf-link ">  <a href="/user/RRezpect" class="yt-user-photo yt-uix-sessionlink      spf-link " data-sessionlink="itct=CC8Q4TkiEwj1qKiXkpvpAhUhGvEFHWbTDTc" >
#       <span class="video-thumb  yt-thumb yt-thumb-48"
#     >
#     <span class="yt-thumb-square">
#       <span class="yt-thumb-clip">
#
#   <img data-thumb="https://yt3.ggpht.com/a/AATXAJz2vMSNFv1YoI4YQjuYbP_zLEabK98eXQrTbQ=s48-c-k-c0xffffffff-no-rj-mo" src="/yts/img/pixel-vfl3z5WfW.gif" height="48" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" data-ytimg="1" width="48" alt="Rezpect" >
#
#         <span class="vertical-align"></span>
#       </span>
#     </span>
#   </span>
#
#   </a>
#   <div class="yt-user-info">
#     <a href="/channel/UC5dbbmnZOPnRAMOcUTgEVSQ" class="yt-uix-sessionlink       spf-link " data-sessionlink="itct=CC8Q4TkiEwj1qKiXkpvpAhUhGvEFHWbTDTc" >Rezpect</a>
#   </div>
# <span id="watch7-subscription-container"><span class=" yt-uix-button-subscription-container"><span class="unsubscribe-confirmation-overlay-container">
#   <div class="yt-uix-overlay "  data-overlay-style="primary" data-overlay-shape="tiny">
#
#         <div class="yt-dialog hid ">
#     <div class="yt-dialog-base">
#       <span class="yt-dialog-align"></span>
#       <div class="yt-dialog-fg" role="dialog">
#         <div class="yt-dialog-fg-content">
#           <div class="yt-dialog-loading">
#               <div class="yt-dialog-waiting-content">
#       <p class="yt-spinner ">
#         <span title="Ícone A carregar" class="yt-spinner-img  yt-sprite"></span>
#
#     <span class="yt-spinner-message">
# A carregar...
#     </span>
#   </p>
#
#   </div>
#
#           </div>
#           <div class="yt-dialog-content">
#               <div class="unsubscribe-confirmation-overlay-content-container">
#     <div class="unsubscribe-confirmation-overlay-content">
#       <div class="unsubscribe-confirmation-message">
#         Anular a subscrição de Rezpect?
#       </div>
#     </div>
#
#     <div class="yt-uix-overlay-actions">
#       <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default yt-uix-overlay-close" type="button" onclick=";return false;"><span class="yt-uix-button-content">Cancelar</span></button>
#       <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-primary overlay-confirmation-unsubscribe-button yt-uix-overlay-close" type="button" onclick=";return false;"><span class="yt-uix-button-content">Anular subscrição</span></button>
#     </div>
#   </div>
#
#           </div>
#           <div class="yt-dialog-working">
#               <div class="yt-dialog-working-overlay"></div>
#   <div class="yt-dialog-working-bubble">
#     <div class="yt-dialog-waiting-content">
#         <p class="yt-spinner ">
#         <span title="Ícone A carregar" class="yt-spinner-img  yt-sprite"></span>
#
#     <span class="yt-spinner-message">
#         A executar...
#     </span>
#   </p>
#
#       </div>
#   </div>
#
#           </div>
#         </div>
#         <div class="yt-dialog-focus-trap" tabindex="0"></div>
#       </div>
#     </div>
#   </div>
#
#
#   </div>
#
# </span><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-subscribe-branded yt-uix-button-has-icon no-icon-markup yt-uix-subscription-button yt-can-buffer yt-uix-servicelink vve-check" type="button" onclick=";return false;" aria-live="polite" aria-busy="false" data-channel-external-id="UC5dbbmnZOPnRAMOcUTgEVSQ" data-servicelink="CDAQmysiEwj1qKiXkpvpAhUhGvEFHWbTDTcyBXdhdGNo" data-unsubscribe-params="CgIIAxILV2l5SWhpWUxEN00YAA%3D%3D" data-clicktracking="itct=CDAQmysiEwj1qKiXkpvpAhUhGvEFHWbTDTcyBXdhdGNo" data-style-type="branded" data-visibility-tracking="CDAQmysiEwj1qKiXkpvpAhUhGvEFHWbTDTcyBXdhdGNo" data-params="EgIIAxgAIgtXaXlJaGlZTEQ3TQ%3D%3D" data-href="https://accounts.google.com/ServiceLogin?service=youtube&amp;hl=pt-PT&amp;uilel=3&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fnext%3D%252Fchannel%252FUC5dbbmnZOPnRAMOcUTgEVSQ%26continue_action%%253D%26hl%3Dpt-PT%26feature%3Dsubscribe%26app%3Ddesktop%26action_handle_signin%3Dtrue&amp;passive=true" data-show-unsub-confirm-dialog="true"><span class="yt-uix-button-content"><span class="subscribe-label" aria-label="Subscrever">Subscrever</span><span class="subscribed-label" aria-label="Anular subsc.">Subscrito</span><span class="unsubscribe-label" aria-label="Anular subsc.">Anular subsc.</span></span></button><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default yt-uix-button-empty yt-uix-button-has-icon yt-uix-subscription-preferences-button" type="button" onclick=";return false;" aria-live="polite" aria-busy="false" aria-role="button" aria-label="Preferências de subscrição" data-params-none="ChhVQzVkYmJtblpPUG5SQU1PY1VUZ0VWU1ESAggDGAAgBA%3D%3D" data-params-default="ChhVQzVkYmJtblpPUG5SQU1PY1VUZ0VWU1ESAggBGAAgBA%3D%3D" data-params-all="ChhVQzVkYmJtblpPUG5SQU1PY1VUZ0VWU1ESAggCGAAgBA%3D%3D" data-channel-external-id="UC5dbbmnZOPnRAMOcUTgEVSQ"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-subscription-preferences yt-sprite"></span></span></button><span class="yt-subscription-button-subscriber-count-branded-horizontal yt-subscriber-count" title="15 mil" aria-label="15 mil" tabindex="0">15 mil</span>  <span class="subscription-preferences-overlay-container">
#
#   <div class="yt-uix-overlay "  data-overlay-style="primary" data-overlay-shape="tiny">
#
#         <div class="yt-dialog hid ">
#     <div class="yt-dialog-base">
# ...
#
#
#           'BG_P': " ...
#           'BG_IU': "\/\/www.google.com\/js\/bg\/jeQSBy52GP_vj-aLADK6D_RsHFfZXrt-vZElH-uv2ok.js",
#
#
#
#         'COMMENTS_TOKEN': "EkQSC1dpeUloaVlMRDdNwAEAyAEA4AEBogINKP___________wFAAMICGxoXaHR0cHM6Ly93d3cueW91dHViZS5jb20iABgG",
#
#       'GET_PLAYER_EVENT_ID': "",
#       'HL_LOCALE': "pt_PT",
#       'TTS_URL': "",
#       'JS_DELAY_LOAD': 0,
#       'LIST_AUTO_PLAY_VALUE': 1,
#       'SHUFFLE_VALUE': 0,
#       'SKIP_RELATED_ADS': false,
#       'SKIP_TO_NEXT_VIDEO': false,
#       'CONVERSION_CONFIG_DICT': {},
#       'RESOLUTION_TRACKING_ENABLED': false,
#       'WATCH_LEGAL_TEXT_ENABLE_AUTOSCROLL': false,
#       'ADS_DATA': {"check_status":false},
#       'PLAYBACK_ID': "AAWk2SLqUVZgNbvW",
#       'IS_DISTILLER': true,
#       'SHARE_CAPTION': null,
#       'SHARE_REFERER': "",
#       'PLAYLIST_INDEX': null
#     });
#
#
#     yt.setMsg({
#       'EDITOR_AJAX_REQUEST_FAILED': "Ocorreu um problema ao tentar obter dados do servidor. Tente novamente ou volte a carregar a página.",
#       'EDITOR_AJAX_REQUEST_503': "Esta funcionalidade não está disponível de momento. Tente novamente mais tarde.",
#       'LOADING': "A carregar..."    });
#
#
#
#
#       yt.setConfig({
#     'GUIDED_HELP_LOCALE': "pt_PT",
#     'GUIDED_HELP_ENVIRONMENT': "prod"
#   });
#
#   </script>
#
#
# <script >yt.setConfig({INNERTUBE_API_KEY: "AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8",INNERTUBE_API_VERSION: "v1",INNERTUBE_CONTEXT_CLIENT_NAME: 1,INNERTUBE_CONTEXT_CLIENT_VERSION: "1.20200429.03.00",GAPI_HINT_PARAMS: "m;\/_\/scs\/abc-static\/_\/js\/k=gapi.gapi.en.jw7XZHvcak8.O\/d=1\/ct=zgms\/rs=AHpOoo-L1iz4xVj0PCdm2On38RCj6aYemA\/m=__features__",'VISITOR_DATA': "CgtabF94dUhfeko3NCi4j8L1BQ%3D%3D",'DELEGATED_SESSION_ID': null,'GAPI_HOST': "https:\/\/apis.google.com",'GAPI_LOCALE': "pt_PT",'INNERTUBE_CONTEXT_HL': "pt-PT",'INNERTUBE_CONTEXT_GL': "PT",'XHR_APIARY_HOST': "youtubei.youtube.com"});yt.setConfig({'PAGE_NAME': "watch",'LOGGED_IN': false,'SESSION_INDEX': null,'VALID_SESSION_TEMPDATA_DOMAINS': ["www.youtube.com","gaming.youtube.com"],'PARENT_TRACKING_PARAMS': "",'FORMATS_FILE_SIZE_JS': ["%s B","%s kB","%s MB","%s GB","%s TB"],'ONE_PICK_URL': "",'GOOGLEPLUS_HOST': "https:\/\/plus.google.com",'PAGEFRAME_JS': "\/yts\/jsbin\/www-pageframe-vflEuaN0T\/www-pageframe.js",'GAPI_LOADER_URL': "\/yts\/jsbin\/www-gapi-loader-vfllQIyr0\/www-gapi-loader.js",'JS_COMMON_MODULE': "\/yts\/jsbin\/www-en_US-vflF9yZ_Y\/common.js",'PAGE_FRAME_DELAYLOADED_CSS': "\/yts\/cssbin\/www-pageframedelayloaded-vfl0WpMvu.css",'EXPERIMENT_FLAGS': {"web_use_beacon_api_for_ad_click_server_pings":true,"enable_mixed_direction_formatted_strings":true,"autoescape_tempdata_url":true,"service_worker_push_logged_out_prompt_watches":-1,"web_client_counter_random_seed":true,"desktop_notification_set_title_bar":true,"service_worker_push_prompt_delay_microseconds":3888000000000,"desktop_sparkles_light_cta_button":true,"web_gel_debounce_ms":10000,"service_worker_push_enabled":true,"service_worker_push_force_notification_prompt_tag":"1","gfeedback_for_signed_out_users_enabled":true,"log_vis_on_tab_change":true,"polymer_bad_build_labels":true,"no_sub_count_on_sub_button":true,"enable_read_more_format_decoration":true,"polymer_verifiy_app_state":true,"desktop_videowall_companion_wta_support":true,"web_deprecate_service_ajax_map_dependency":true,"desktop_polymer_video_masthead_session_tempdata_ttl":30,"enable_premium_voluntary_pause":true,"prefetch_comments_ms_after_video":0,"app_settings_snapshot_min_time_between_snapshots_hours":24,"desktop_polymer_video_masthead_always_use_responsive_iframe":true,"csi_on_gel":true,"autoplay_pause_by_lact_sec":0,"delay_gel_until_config_ready":true,"service_worker_enabled":true,"html5_experiment_id_label":0,"web_logging_max_batch":150,"warm_load_nav_start_web":true,"enable_ypc_spinners":true,"live_chat_unicode_emoji_json_url":"https:\/\/www.gstatic.com\/youtube\/img\/emojis\/emojis-svg-4.json","enable_watch_next_pause_autoplay_lact":true,"should_clear_video_data_on_player_cued_unstarted":true,"mdx_enable_privacy_disclosure_ui":true,"enable_docked_chat_messages":true,"disable_legacy_desktop_remote_queue":true,"web_op_endpoint_blacklist":["liveChatActionEndpoint"],"cancel_pending_navs":true,"service_worker_scope":"\/","desktop_image_companion_wta_support":true,"consent_url_override":"","web_op_signal_type_blacklist":[],"enable_ve_tracker_key":true,"desktop_pyv_on_watch_missing_params":true,"botguard_periodic_refresh":true,"overwrite_polyfill_on_logging_lib_loaded":true,"disable_thumbnail_preloading":true,"web_yt_config_context":true,"suppress_gen_204":true,"desktop_shopping_companion_wta_support":true,"desktop_notification_high_priority_ignore_push":true,"use_watch_fragments2":true,"web_always_load_chat_support":true,"watch_next_pause_autoplay_lact_sec":4500,"web_post_search":true,"log_web_meta_interval_ms":0,"web_op_continuation_type_blacklist":[],"service_worker_push_home_page_prompt":true,"disable_simple_mixed_direction_formatted_strings":true,"web_screen_manager_use_default_client":true,"log_window_onerror_fraction":0.1,"web_screen_associated_all_layers":true,"web_api_url":true,"service_worker_push_prompt_cap":-1,"desktop_pyv_on_watch_override_lact":true,"network_polling_interval":30000,"pass_biscotti_id_in_header_ajax":true,"live_chat_inc ...
#     'GUIDED_HELP_LOCALE': "pt_PT",
#     'GUIDED_HELP_ENVIRONMENT': "prod"
#   });
# yt.setConfig('SPF_SEARCH_BOX', true);yt.setMsg({'ADDTO_CREATE_NEW_PLAYLIST': "Criar nova lista de reprodução\n",'ADDTO_CREATE_PLAYLIST_DYNAMIC_TITLE': "  $dynamic_title_placeholder (criar nova)\n",'ADDTO_WATCH_LATER': "Watch later",'ADDTO_WATCH_LATER_ADDED': "Adicionado",'ADDTO_WATCH_LATER_ERROR': "Erro",'ADDTO_WATCH_QUEUE': "Watch Queue",'ADDTO_WATCH_QUEUE_ADDED': "Adicionado",'ADDTO_WATCH_QUEUE_ERROR': "Erro",'ADDTO_TV_QUEUE': "Queue",'MASTHEAD_NOTIFICATIONS_LABEL': {"other": "# notifica\u00e7\u00f5es n\u00e3o lidas.", "case0": "0 notifica\u00e7\u00f5es n\u00e3o lidas.", "case1": "1 notifica\u00e7\u00e3o n\u00e3o lida."},'MASTHEAD_NOTIFICATIONS_COUNT_99PLUS': "99+",'MDX_AUTOPLAY_OFF': 'Reprodução automática desativada','MDX_AUTOPLAY_ON': 'Reprodução automática ativada'});  yt.setConfig('FEED_PRIVACY_CSS_URL', "\/yts\/cssbin\/www-feedprivacydialog-vfl3mbjRm.css");
#   yt.setConfig('FEED_PRIVACY_LIGHTBOX_ENABLED', true);
# yt.setConfig({'SBOX_JS_URL': "\/yts\/jsbin\/www-searchbox-vflgDUKEY\/www-searchbox.js",'SBOX_SETTINGS': {"REQUEST_DOMAIN":"pt","HAS_ON_SCREEN_KEYBOARD":true,"SUGG_EXP_ID":"ytrl_pls_v1_c1,cfro=1,ersl=true,mrfs=true,drsl=true,rac=true,eap=true,mlrt=1,rlmn=ng3_pls_log_tiered_20200421_ast_proto.recordio","REQUEST_LANGUAGE":"pt-PT"},'SBOX_LABELS': {"SUGGESTION_DISMISSED_LABEL":"Sugestão removida","SUGGESTION_DISMISS_LABEL":"Remover"}});  yt.setConfig({
#     'YPC_LOADER_JS': "\/yts\/jsbin\/www-ypc-vfl18p1Ww\/www-ypc.js",
#     'YPC_LOADER_CSS': "\/yts\/cssbin\/www-ypc-vflVd_jtI.css",
#     'YPC_SIGNIN_URL': "https:\/\/accounts.google.com\/ServiceLogin?service=youtube\u0026hl=pt-PT\u0026uilel=3\u0026continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fnext%3D%252F%26hl%3Dpt-PT%26app%3Ddesktop%26action_handle_signin%3Dtrue\u0026passive=true",
#     'DBLCLK_ADVERTISER_ID': "2542116",
#     'DBLCLK_YPC_ACTIVITY_GROUP': "youtu444",
#     'SUBSCRIPTION_URL': "\/subscription_ajax",
#     'YPC_SWITCH_URL': "\/signin?next=%2F\u0026feature=purchases\u0026skip_identity_prompt=True\u0026action_handle_signin=true",
#     'YPC_GB_LANGUAGE': "pt_PT",
#     'YPC_MB_URL': "https:\/\/payments.youtube.com\/payments\/v4\/js\/integrator.js?ss=md",
#     'YPC_TRANSACTION_URL': "\/transaction_handler",
#     'YPC_SUBSCRIPTION_URL': "\/ypc_subscription_ajax",
#     'YPC_POST_PURCHASE_URL': "\/ypc_post_purchase_ajax",
#     'YTR_FAMILY_CREATION_URL': "https:\/\/families.google.com\/webcreation?usegapi=1",
#     'YTO_GTM_DATA': {'event': 'purchased', 'purchaseStatus': 'success'},
#     'YTO_GTM_1_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '1'},
#     'YTO_GTM_2_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '2'}
#   });
#   yt.setMsg({
#     'YPC_OFFER_OVERLAY': "  \n",
#     'YPC_UNSUBSCRIBE_OVERLAY': "  \n"
#   });
#   yt.setConfig('GOOGLE_HELP_CONTEXT', "watch");
# ytcsi.info('st', 371);ytcfg.set({"CSI_SERVICE_NAME":"youtube","TIMING_INFO":{"yt_lt":"cold","yt_pl":0,"GetPlayer_rid":"0x637ed71cad4d718f","c":"WEB","cver":"1.20200429.03.00","yt_li":"0","GetWatchNext_rid":"0x637ed71cad4d718f"}});;ytcfg.set({"CSI_VIEWPORT":true,"TIMING_ACTION":"watch"});;  yt.setConfig({
#       'XSRF_TOKEN': "",
#       'XSRF_FIELD_NAME': "session_token",
#
#       'XSRF_REDIRECT_TOKEN': "1cSX1jgEdfZHX4i0u6RyYMjljAB8MTU4ODcxMzc4NEAxNTg4NjI3Mzg0"  });
# yt.setConfig('ID_TOKEN', null);yt.setConfig('INNERTUBE_CONTEXT', {"client":{"hl":"pt-PT","gl":"PT","visitorData":"CgtabF94dUhfeko3NCi4j8L1BQ%3D%3D","userAgent":"python-requests/2.22.0,gzip(gfe)","clientName":"WEB","clientVersion":"1.20200429.03.00"},"request":{"sessionId":"6823102660322485808"}});window.ytcfg.set('SERVICE_WORKER_KILLSWITCH', false);  yt.setConfig('THUMB_DELAY_LOAD_BUFFER', 0);
# if (window.ytcsi) {window.ytcsi.tick("jl", null, '');}</script>
# </body></html>
